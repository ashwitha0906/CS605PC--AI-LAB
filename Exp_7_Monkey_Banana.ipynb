# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwitha0906/CS605PC--AI-LAB/blob/main/Exp_7_Monkey_Banana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def monkey(state):

  print("Initial state",state)
  state["monkey"]=state["box"]
  state["box"]=state["banana"]
  state["banana"]=state["box"]
  print("Final state",state)
one= input("Enter monkey position")
two=input("enter box position")
three=input("enter banana position")
state={"monkey":one,"box":two,"banana":three}
monkey(state)
# Out:
# Enter monkey position 6
# enter box position5
# enter banana position3
# Initial state {'monkey': ' 6', 'box': '5', 'banana': '3'}
# Final state {'monkey': '5', 'box': '3', 'banana': '3'}

# %%
def monkey(state):

  print("Initial state",state)
  state["monkey"]=state["box"]
  state["box"]=state["banana"]
  state["banana"]=state["box"]
  print("Final state",state)
corner= input("Enter banana position")
left=input("enter box position")
right=input("enter monkey position")
state={"banana":corner,"box":left,"monkey":right}
monkey(state)
# Out:
# Enter banana position corner
# enter box position left
# enter monkey position right
# Initial state {'banana': ' corner', 'box': ' left', 'monkey': ' right'}
# Final state {'banana': ' corner', 'box': ' corner', 'monkey': ' left'}
